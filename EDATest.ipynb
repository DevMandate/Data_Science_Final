# %%
import pandas 
data = pandas.read_csv('datasets/Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual_Income  Spending_Score
# 0             1    Male   19           15.0            39.0
# 1             2    Male   21           15.0            81.0
# 2             3  Female   20           16.0             6.0
# 3             4  Female   23           16.0            77.0
# 4             5  Female   31           17.0            40.0
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35          120.0            79.0
# 196         197  Female   45          126.0             NaN
# 197         198    Male   32          126.0            74.0
# 198         199    Male   32          137.0            18.0
# 199         200    Male   30          137.0            83.0
#
# [200 rows x 5 columns]

# %%
# check whether you have empty sets
data.isnull().sum()
# Out:
# CustomerID        0
# Gender            4
# Age               0
# Annual_Income     1
# Spending_Score    3
# dtype: int64

# %%
# Filling the empty spots 
data['Gender'].fillna('N/A', inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\1800340951.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].fillna('N/A', inplace=True)

# %%
# Filling empty Annual Income and Spending Score
mean_Annual = data['Annual_Income'].mean()
mean_Annual
# Out:
# np.float64(60.35678391959799)

# %%
mean_Spending = data['Spending_Score'].mean()
mean_Spending
# Out:
# np.float64(50.3248730964467)

# %%
# Filling the empty spots 
data['Annual_Income'].fillna('mean_Annual', inplace=True)
data['Spending_Score'].fillna('mean_Spending', inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\1007759809.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Annual_Income'].fillna('mean_Annual', inplace=True)
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\1007759809.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'mean_Annual' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
data.head(50)
# Out:
#     CustomerID  Gender  Age Annual_Income Spending_Score
# 0            1    Male   19          15.0           39.0
# 1            2    Male   21          15.0           81.0
# 2            3  Female   20          16.0            6.0
# 3            4  Female   23          16.0           77.0
# 4            5  Female   31          17.0           40.0
# 5            6  Female   22          17.0           76.0
# 6            7  Female   35          18.0            6.0
# 7            8  Female   23          18.0           94.0
# 8            9    Male   64          19.0            3.0
# 9           10  Female   30          19.0           72.0
# 10          11    Male   67          19.0           14.0
# 11          12  Female   35          19.0           99.0
# 12          13  Female   58          20.0           15.0
# 13          14  Female   24          20.0           77.0
# 14          15    Male   37          20.0           13.0
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID        0
# Gender            0
# Age               0
# Annual_Income     0
# Spending_Score    0
# dtype: int64

# %%
data.describe()
# Out:
#        CustomerID         Age
# count  200.000000  200.000000
# mean   100.500000   38.850000
# std     57.879185   13.969007
# min      1.000000   18.000000
# 25%     50.750000   28.750000
# 50%    100.500000   36.000000
# 75%    150.250000   49.000000
# max    200.000000   70.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# use one of the versions
plt.style.use(['seaborn-v0_8'])

# %%
sn.countplot(x=data['Gender'], palette='spring')
plt.title('Gender Count of HHDS')
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\340801812.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(x=data['Gender'], palette='spring')
# Text(0.5, 1.0, 'Gender Count of HHDS')

# %%
# Import Numpy library that will enable working with arrays and matrices
import numpy

# %%
sn.barplot(x='Gender', y='Spending_Score', data=data, estimator=numpy.mean, palette='winter')
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\734219230.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x='Gender', y='Spending_Score', data=data, estimator=numpy.mean, palette='winter')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "mean_Spending"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sn.barplot(x='Gender', y='Spending_Score', data=data, estimator=numpy.mean, palette='winter')
#
# ...

# %%
data[140:151]
# Out:
#      CustomerID  Gender  Age Annual_Income Spending_Score
# 140         141  Female   57          75.0            5.0
# 141         142    Male   32          75.0           93.0
# 142         143  Female   28          76.0           40.0
# 143         144  Female   32          76.0           87.0
# 144         145    Male   25          77.0           12.0
# 145         146    Male   28          77.0           97.0
# 146         147    Male   48          77.0           36.0
# 147         148  Female   32          77.0           74.0
# 148         149  Female   34          78.0           22.0
# 149         150    Male   34          78.0  mean_Spending
# 150         151     N/A   43          78.0           17.0

# %%
# Step 1: Convert the 'Spending_Score' column to numeric, coercing errors to NaN
data['Spending_Score'] = pandas.to_numeric(data['Spending_Score'], errors='coerce')

# %%
# Step 2: Calculate the mean of the 'Spending_Score' column, ignoring NaN values
mean_value = data['Spending_Score'].mean()

# %%
# Step 3: Replace NaN values with the mean of the column
data['Spending_Score'].fillna(mean_value, inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\75725224.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Spending_Score'].fillna(mean_value, inplace=True)

# %%
data[140:151]
# Out:
#      CustomerID  Gender  Age Annual_Income  Spending_Score
# 140         141  Female   57          75.0        5.000000
# 141         142    Male   32          75.0       93.000000
# 142         143  Female   28          76.0       40.000000
# 143         144  Female   32          76.0       87.000000
# 144         145    Male   25          77.0       12.000000
# 145         146    Male   28          77.0       97.000000
# 146         147    Male   48          77.0       36.000000
# 147         148  Female   32          77.0       74.000000
# 148         149  Female   34          78.0       22.000000
# 149         150    Male   34          78.0       50.324873
# 150         151     N/A   43          78.0       17.000000

# %%
sn.barplot(x='Gender', y='Spending_Score', data=data, estimator=numpy.mean, palette='winter')
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\734219230.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x='Gender', y='Spending_Score', data=data, estimator=numpy.mean, palette='winter')
# <Axes: xlabel='Gender', ylabel='Spending_Score'>

# %%
# Convert the columns to numeric, coercing errors to NaN
data['Age'] = pandas.to_numeric(data['Age'], errors='coerce')
data['Annual_Income'] = pandas.to_numeric(data['Annual_Income'], errors='coerce')
data['Spending_Score'] = pandas.to_numeric(data['Spending_Score'], errors='coerce')

# Now calculate the mean of these columns
mean_values = data[['Age', 'Annual_Income', 'Spending_Score']].mean()

print(mean_values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 2
#       1 # Convert the columns to numeric, coercing errors to NaN
# ...

# %%
# check whether you have empty sets
data.isnull().sum()
# Out:
# customerid        0
# gender            0
# age               0
# annual_income     0
# spending_score    0
# dtype: int64

# %%
# What datatypes does the different columns hold
data.dtypes
# Out:
# customerid         int64
# gender            object
# age                int64
# annual_income     object
# spending_score    object
# dtype: object

# %%
data[140:151]
# Out:
#      customerid  gender  age annual_income spending_score
# 140         141  Female   57          75.0            5.0
# 141         142    Male   32          75.0           93.0
# 142         143  Female   28          76.0           40.0
# 143         144  Female   32          76.0           87.0
# 144         145    Male   25          77.0           12.0
# 145         146    Male   28          77.0           97.0
# 146         147    Male   48          77.0           36.0
# 147         148  Female   32          77.0           74.0
# 148         149  Female   34          78.0           22.0
# 149         150    Male   34          78.0  mean_Spending
# 150         151     N/A   43          78.0           17.0

# %%
# Step 1: Convert the 'Spending_Score' column to numeric, coercing errors to NaN
data['age'] = pandas.to_numeric(data['age'], errors='coerce')
data['annual_income'] = pandas.to_numeric(data['annual_income'], errors='coerce')
data['spending_score'] = pandas.to_numeric(data['spending_score'], errors='coerce')

# %%
# Step 2: Calculate the mean of the columns
mean_value = data['age'].mean()
mean_value = data['annual_income'].mean()
mean_value = data['spending_score'].mean()

# %%
# Step 3: Replace NaN values with the mean of the column
data['age'].fillna(mean_value, inplace=True)
data['annual_income'].fillna(mean_value, inplace=True)
data['spending_score'].fillna(mean_value, inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\1446050129.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['age'].fillna(mean_value, inplace=True)
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\1446050129.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data[140:151]
# Out:
#      customerid  gender  age  annual_income  spending_score
# 140         141  Female   57           75.0        5.000000
# 141         142    Male   32           75.0       93.000000
# 142         143  Female   28           76.0       40.000000
# 143         144  Female   32           76.0       87.000000
# 144         145    Male   25           77.0       12.000000
# 145         146    Male   28           77.0       97.000000
# 146         147    Male   48           77.0       36.000000
# 147         148  Female   32           77.0       74.000000
# 148         149  Female   34           78.0       22.000000
# 149         150    Male   34           78.0       50.324873
# 150         151     N/A   43           78.0       17.000000

# %%
means = mean_values 
plt.figure(figsize=(8,5))
sn.barplot(x=means.index, y=means.values, palette='viridis')
plt.title('Mean Values of Age, Annual Income, and Spending Score')
plt.xlabel('Categories')
plt.ylabel('Mean Value')
plt.show()
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\71185378.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(x=means.index, y=means.values, palette='viridis')

# %%
mode = data[['Age', 'Annual_Income', 'Spending_Score']].mode()
print(mode)
# Out:
#     Age  Annual_Income  Spending_Score
# 0  32.0           54.0            42.0
# 1   NaN           78.0             NaN

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
sn.scatterplot(x='age', y='annual_income', data=data, palette='spring')
plt.title('Scatter Plot of Age vs Annual Income')
plt.xlabel('age')
plt.ylabel('annual income')
plt.show()
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_9964\2237370789.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sn.scatterplot(x='age', y='annual_income', data=data, palette='spring')

# %%
# Calculate correlation
correlation = data['age'].corr(data['annual_income'])
print(f'Correlation between age and annual income: {correlation}')
# Out:
# Correlation between age and annual income: -0.004894976636004966

# %%
import statsmodels.api as sm

# Prepare the data for regression
X = data['age']  # Independent variable
y = data['annual_income']  # Dependent variable

# Add a constant to the independent variable
X = sm.add_constant(X)

# Create and fit the model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          annual_income   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                  0.004744
# Date:                Fri, 18 Oct 2024   Prob (F-statistic):              0.945
# Time:                        05:33:40   Log-Likelihood:                -935.80
# No. Observations:                 200   AIC:                             1876.
# Df Residuals:                     198   BIC:                             1882.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         60.6622      5.484     11.062      0.000      49.848      71.476
# ...
