# %%
# Exploratory Data Analysis
# We shall use pandas to read our CSV file (bank)

import pandas

data = pandas.read_csv('datasets/bank.csv')
data
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
# printing ot a single column 
data['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
# check whether you have empty sets
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Filling the empty spots on the self_employed column
data['Self_Employed'].fillna('unknown', inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_13040\2034542119.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Self_Employed'].fillna('unknown', inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.head(50)
# Out:
#      Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0   LP001002    Male      No      Graduate            No             5849
# 1   LP001003    Male     Yes      Graduate            No             4583
# 2   LP001005    Male     Yes      Graduate           Yes             3000
# 3   LP001006    Male     Yes  Not Graduate            No             2583
# 4   LP001008    Male      No      Graduate            No             6000
# 5   LP001011    Male     Yes      Graduate           Yes             5417
# 6   LP001013    Male     Yes  Not Graduate            No             2333
# 7   LP001014    Male     Yes      Graduate            No             3036
# 8   LP001018    Male     Yes      Graduate            No             4006
# 9   LP001020    Male     Yes      Graduate            No            12841
# 10  LP001024    Male     Yes      Graduate            No             3200
# 11  LP001027    Male     Yes      Graduate       unknown             2500
# ...

# %%
mean_loan = data['LoanAmount'].mean()
mean_loan
# Out:
# np.float64(146.41216216216216)

# %%
# Replace all the empty slots in the loan_mean column with the mean gotten
data['LoanAmount'].fillna(mean_loan, inplace=True)
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_13040\1273243336.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(mean_loan, inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.head(60)
# Out:
#      Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0   LP001002    Male      No      Graduate            No             5849
# 1   LP001003    Male     Yes      Graduate            No             4583
# 2   LP001005    Male     Yes      Graduate           Yes             3000
# 3   LP001006    Male     Yes  Not Graduate            No             2583
# 4   LP001008    Male      No      Graduate            No             6000
# 5   LP001011    Male     Yes      Graduate           Yes             5417
# 6   LP001013    Male     Yes  Not Graduate            No             2333
# 7   LP001014    Male     Yes      Graduate            No             3036
# 8   LP001018    Male     Yes      Graduate            No             4006
# 9   LP001020    Male     Yes      Graduate            No            12841
# 10  LP001024    Male     Yes      Graduate            No             3200
# 11  LP001027    Male     Yes      Graduate       unknown             2500
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  614.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   84.037468
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.250000
# 50%        3812.500000        1188.500000  129.000000
# 75%        5795.000000        2297.250000  164.750000
# max       81000.000000       41667.000000  700.000000

# %%
# check the number of males vs females
data.groupby('Gender').size()
# Out:
# Gender
# Female    125
# Male      489
# dtype: int64

# %%
data.groupby(['Gender', 'Married', 'Education', 'Property_Area']).size()
# Out:
# Gender  Married  Education     Property_Area
# Female  No       Graduate      Rural             15
#                                Semiurban         30
#                                Urban             24
#                  Not Graduate  Rural              4
#                                Semiurban          6
#                                Urban              4
#         Yes      Graduate      Rural              6
#                                Semiurban         21
#                                Urban              8
#                  Not Graduate  Rural              3
#                                Semiurban          4
# Male    No       Graduate      Rural             31
#                                Semiurban         33
#                                Urban             35
#                  Not Graduate  Rural             13
#                                Semiurban         11
#                                Urban              7
# ...

# %%
# What datatypes does the different columns hold
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Checking versions available on matplotib library
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# use one of the versions
plt.style.use(['seaborn-v0_8'])

# %%
# by use of matplotlib, we draw a count plot bar
# A count plot is a univariate meaning it only accepts one column
ax = sn.countplot(x= data['Property_Area'], palette='spring')
plt.title('Property Area Owned by HHDS')
plt.ylabel('Total Number of HHDS')
plt.xlabel('HHDS Setting')
total = len(data)
for p in ax.patches:
    height = p.get_height()
    percentage = 100 * height / total
    ax.text(p.get_x() + p.get_width()/2., height, f'{height:.0f}\n({percentage:.1f}%)', ha='center')

# Show plot
plt.show()
# Out:
# C:\Users\Caleb\AppData\Local\Temp\ipykernel_13040\2160569371.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sn.countplot(x= data['Property_Area'], palette='spring')

# %%
# Below we are going to import Numpy linrary that will enable us to work with arrays and matrices
import numpy

# %%
# creating bar plots
# Bar plots are  bivariate or multivariate - they accept two or more columns
# Note:  A barplot is drawn by use of a categorical data combined with a quantitatve data/column

sn.barplot(x='Property_Area', y='LoanAmount', data=data, estimator=numpy.mean, palette='winter', hue='Married')
# Out:
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
# A swarm plot
# A swarm plot is a plot that helps to visualize where more members of a certain group lies/fall
# It shows the distribution of different members
# is a bivariate or multivariate 

sn.swarmplot(x='Gender', y='ApplicantIncome', data=data, palette='magma', hue='Education')
# Out:
# C:\Users\Caleb\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
# C:\Users\Caleb\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 53.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Caleb\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# Scatter plot (Quantitative columns only)
# It is used to show distribution of different entities of a column
# It is also used to show the relationship between the 2 variables

sn.scatterplot(x='LoanAmount', y='ApplicantIncome', data=data, palette='spring', hue='Property_Area')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
# PieChart
# It is univariate

data.groupby('Loan_Status').size().plot(kind="pie", autopct = '%1.1f%%')
# Out:
# <Axes: >

# %%
data.groupby('Loan_Status').size().plot(kind="line")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
data.groupby('Loan_Status').size().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
