# %%
#import pandas and read the data
import pandas
data = pandas.read_csv('datasets/Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual_Income  Spending_Score
# 0             1    Male   19           15.0            39.0
# 1             2    Male   21           15.0            81.0
# 2             3  Female   20           16.0             6.0
# 3             4  Female   23           16.0            77.0
# 4             5  Female   31           17.0            40.0
# ..          ...     ...  ...            ...             ...
# 195         196  Female   35          120.0            79.0
# 196         197  Female   45          126.0             NaN
# 197         198    Male   32          126.0            74.0
# 198         199    Male   32          137.0            18.0
# 199         200    Male   30          137.0            83.0
#
# [200 rows x 5 columns]

# %%
# check for empty slots
data.isnull().sum()
# Out:
# CustomerID        0
# Gender            4
# Age               0
# Annual_Income     1
# Spending_Score    3
# dtype: int64

# %%
# Drop/ignore the empty slots on the data
data.dropna(inplace=True)

# %%
# check for empty slots again
data.isnull().sum()
# Out:
# CustomerID        0
# Gender            0
# Age               0
# Annual_Income     0
# Spending_Score    0
# dtype: int64

# %%
# Create an array where you replace your predicts
array = data.values
our_data = array[:, 2:5]
our_data
# Out:
# array([[19, 15.0, 39.0],
#        [21, 15.0, 81.0],
#        [20, 16.0, 6.0],
#        [23, 16.0, 77.0],
#        [31, 17.0, 40.0],
#        [22, 17.0, 76.0],
#        [35, 18.0, 6.0],
#        [23, 18.0, 94.0],
#        [64, 19.0, 3.0],
#        [30, 19.0, 72.0],
#        [67, 19.0, 14.0],
#        [35, 19.0, 99.0],
#        [58, 20.0, 15.0],
#        [24, 20.0, 77.0],
#        [37, 20.0, 13.0],
#        [22, 20.0, 79.0],
#        [35, 21.0, 35.0],
#        [20, 21.0, 66.0],
#        [52, 23.0, 29.0],
#        [35, 23.0, 98.0],
#        [35, 24.0, 35.0],
#        [25, 24.0, 73.0],
#        [46, 25.0, 5.0],
#        [31, 25.0, 73.0],
#        [54, 28.0, 14.0],
#        [29, 28.0, 82.0],
#        [45, 28.0, 32.0],
#        [35, 28.0, 61.0],
#        [40, 29.0, 31.0],
#        [23, 29.0, 87.0],
#        [60, 30.0, 4.0],
#        [21, 30.0, 73.0],
#        [53, 33.0, 4.0],
#        [18, 33.0, 92.0],
#        [49, 33.0, 14.0],
#        [21, 33.0, 81.0],
#        [42, 34.0, 17.0],
# ...

# %%
# when dealing with numerical/quantitave data, you use KMeans
# For categorical data, we use KModes
# For the combination, we use KPrototype
from sklearn.cluster import KMeans
model = KMeans(10, random_state=42)
model.fit(our_data)
# Out:
# KMeans(n_clusters=10, random_state=42)

# %%
# List out the groups / clusters created by the model
means = model.cluster_centers_
means
# Out:
# array([[ 42.38461538,  47.30769231,  46.73076923],
#        [ 32.58064516,  80.4516129 ,  82.70967742],
#        [ 43.75      , 106.5       ,  19.875     ],
#        [ 25.27272727,  25.72727273,  79.36363636],
#        [ 51.41666667,  25.16666667,  11.5       ],
#        [ 25.        ,  60.37037037,  48.77777778],
#        [ 60.20689655,  55.89655172,  50.4137931 ],
#        [ 41.17391304,  79.13043478,  15.39130435],
#        [ 32.625     ,  23.375     ,  30.5       ],
#        [ 33.83333333, 117.        ,  80.16666667]])

# %%
# Use a dataframe to represent the clusters
clusters = pandas.DataFrame(means, columns=['Age', 'Income', 'Spending_Score'])
clusters
# Out:
#          Age      Income  Spending_Score
# 0  42.384615   47.307692       46.730769
# 1  32.580645   80.451613       82.709677
# 2  43.750000  106.500000       19.875000
# 3  25.272727   25.727273       79.363636
# 4  51.416667   25.166667       11.500000
# 5  25.000000   60.370370       48.777778
# 6  60.206897   55.896552       50.413793
# 7  41.173913   79.130435       15.391304
# 8  32.625000   23.375000       30.500000
# 9  33.833333  117.000000       80.166667

# %%
# Show members of one of the clusters
data['Cluster_number'] = model.labels_
clusters = data[data['Cluster_number'] == 3]
clusters
# Out:
#     CustomerID  Gender  Age  Annual_Income  Spending_Score  Cluster_number
# 1            2    Male   21           15.0            81.0               3
# 3            4  Female   23           16.0            77.0               3
# 5            6  Female   22           17.0            76.0               3
# 7            8  Female   23           18.0            94.0               3
# 9           10  Female   30           19.0            72.0               3
# 11          12  Female   35           19.0            99.0               3
# 13          14  Female   24           20.0            77.0               3
# 15          16    Male   22           20.0            79.0               3
# 17          18    Male   20           21.0            66.0               3
# 19          20  Female   35           23.0            98.0               3
# 21          22    Male   25           24.0            73.0               3
# ...

# %%
# Export members of a particular clusterinto a csv
data[data['Cluster_number'] == 3].to_csv('Cluster_3_member.csv')
